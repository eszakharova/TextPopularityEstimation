# %%
import csv
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data_preprocessed.csv', sep = ';', encoding='cp1251')

# %%
import matplotlib.pyplot as plt
% matplotlib inline
fig = plt.figure(figsize = (7,7))
plt.hist(data['LikesNormAvg'], bins = 300, color = 'pink')
plt.xlim(0,1000)
plt.show()

# %% [markdown]
# ## Если поделить на среднее число лайков для каждой группы в выборке (и результат умножить на 100)

# %%
y = data['LikesNormAvg'].astype(float)
true_likes = data['Likes'].astype(int)
coef = data['AvgLikes'].astype(float)/100
texts = data['Text']
categ = data['Type']
X = data.drop(['Text','LikesNormAvg', 'LikesNormFlw', 'Likes', 'AvgLikes',
       'Followers', 'GroupId', 'Type', 'Date'], axis =1)

# %%
types = pd.get_dummies(categ)

# %%
X = pd.concat((X, types), axis = 1).astype(int)

# %%
def load_stop_words():
    file = open('../preprocessing/stop_words.txt', 'r')
    lines = file.readlines()
    stop_words = []
    for line in lines:
        stop_words.append(line.strip())
    return stop_words

# %%
sw = load_stop_words()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(analyzer='word', stop_words=sw, lowercase=True, min_df = 5)

# %%
texts_tfidf = tfidf.fit_transform(texts)

# %%
# names = tfidf.get_feature_names()

# %%
texts_tfidf.shape
# Out:
# (6689, 9519)

# %%
# texts_arr = texts_tfidf.toarray()

# %%
from scipy.sparse import csr_matrix, hstack, vstack
X_sparse = csr_matrix(X)
X_all_sparse =  hstack((X_sparse, texts_tfidf))

# %%
state = 27

# %%
from sklearn.model_selection import KFold, cross_val_predict
kf = KFold(n_splits = 5, random_state = state)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.utils.validation import check_array as check_arrays
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = check_arrays(y_true, y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
def quality(y_true, y_pred):
    print('MAE:')
    print(mean_absolute_error(y_true, y_pred))
    print('MSE:')
    print(mean_squared_error(y_true, y_pred))
    print('RMSE:')
    print(np.sqrt(mean_squared_error(y_true, y_pred)))
#     print('MAPE')
#     print(mean_absolute_percentage_error(y_true, y_pred))

# %%
def plot_error(y_true, y_pred):
    fig = plt.figure(figsize =  (15, 6))
    plt.plot(y_true, color = 'magenta', label = 'true')
    plt.plot(y_pred, color = 'grey', alpha = 0.8, label = 'predicted' )
    plt.legend()

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
frst = RandomForestRegressor(n_estimators = 300)

# %%
# pred_raw = cross_val_predict(frst, X_all_sparse, y, cv = kf, verbose = 10, n_jobs = 2)

# %% [markdown]
# #### Для отмасштабированного целевого вектора

# %%
quality(y, pred_raw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-f42fac062586> in <module>()
# ----> 1 quality(y, pred_raw)
#
# NameError: name 'pred_raw' is not defined

# %%
plot_error(y, pred_raw)

# %% [markdown]
# #### Для изначального кол-ва лайков

# %%
quality(true_likes, pred_raw*coef)

# %%
plot_error(true_likes, pred_raw*coef)

# %% [markdown]
# ### SGD

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd = SGDRegressor()

# %%
pred_raw_sgd = cross_val_predict(sgd, X_all_sparse, y, cv = kf, verbose = 10, n_jobs = 2)
# Out:
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Batch computation too fast (0.0797s.) Setting batch_size=4.
# [Parallel(n_jobs=2)]: Done   3 out of   5 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=2)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done   5 out of   5 | elapsed:    0.2s finished

# %%
quality(y, pred_raw_sgd)
plot_error(y, pred_raw_sgd)
# Out:
# MAE:
# 1.31258955079e+12
# MSE:
# 1.2170080994e+25
# RMSE:
# 3.48856431702e+12

# %%
quality(true_likes, pred_raw_sgd*coef)
plot_error(true_likes, pred_raw_sgd*coef)
# Out:
# MAE:
# 5.2134644049e+13
# MSE:
# 3.64129089977e+28
# RMSE:
# 1.90821668051e+14

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVR
svr = SVR(kernel = 'poly')

# %%
pred_raw_svm = cross_val_predict(svr, X_all_sparse, y, cv = kf, verbose = 10, n_jobs = -1)
# Out:
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  1.7min remaining:  2.5min
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:  1.8min remaining:  1.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.0min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.0min finished

# %%
quality(y, pred_raw_svm)
plot_error(y, pred_raw_svm)
# Out:
# MAE:
# 43.4518160761
# MSE:
# 5023.94586776
# RMSE:
# 70.8797987283

# %%
quality(true_likes, pred_raw_svm*coef)
plot_error(true_likes, pred_raw_svm*coef)
# Out:
# MAE:
# 1017.6316167
# MSE:
# 6049205.27562
# RMSE:
# 2459.51321924

# %%
# from xgboost import XGBRegressor
# xgb = XGBRegressor(n_estimators = 15, max_depth = 5)
# Out:
# /home/lena/anaconda3/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()

# %%
pred_raw_knn = cross_val_predict(knn, X_all_sparse, y, cv = kf, verbose = 10, n_jobs = -1)
# Out:
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    1.9s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:    2.0s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.4s finished

# %%
quality(y, pred_raw_knn)
plot_error(y, pred_raw_knn)
# Out:
# MAE:
# 48.992542242
# MSE:
# 5827.42412935
# RMSE:
# 76.3375669598

# %%
quality(true_likes, pred_raw_knn*coef)
plot_error(true_likes, pred_raw_knn*coef)
# Out:
# MAE:
# 1215.4475204
# MSE:
# 9267942.74725
# RMSE:
# 3044.32960555

# %% [markdown]
# ## Если оставить числ лайков как есть, а число подписчиков и среднее сделать признаками

# %%
flw_sparse = csr_matrix(data['Followers'].reshape(-1, 1))
likes_sparse = csr_matrix(data['AvgLikes'].reshape(-1, 1))

# %%
X_raw = hstack((X_all_sparse, flw_sparse, likes_sparse))

# %%
# frst_light = RandomForestRegressor(n_estimators = 35)

# %%
# pred = cross_val_predict(frst, X_raw, true_likes, cv = kf, verbose = 10)

# %%
pred_knn = cross_val_predict(knn, X_raw, true_likes, cv = kf, verbose = 10)
# Out:
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.7s finished

# %%
quality(true_likes, pred_knn)
# Out:
# MAE:
# 1655.5822096
# MSE:
# 12543094.5664
# RMSE:
# 3541.62315421

# %%
plot_error(true_likes, pred_knn)
